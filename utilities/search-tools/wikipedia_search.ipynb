# %% [markdown]
# ## Wikipedia Search
# ### Supports extracting texts, sections, links, categories, translations, etc from Wikipedia.

# %%
#!pip install wikipedia-api
#https://pypi.org/project/Wikipedia-API/

# %%
import wikipediaapi

def search_wiki(topic):
    wiki_wiki = wikipediaapi.Wikipedia(user_agent='MyProjectName (brajens@live.com)', language='en')

    page_py = wiki_wiki.page(query)

    if page_py.exists():
        return  "Content: {0}. Source: {1}".format(page_py.summary[0:500], page_py.fullurl)
    else:
        print("Conent: Page not found. Source: None")

# %%
query = 'Python_(programming_language)'
print(search_wiki(query))
